# %% [markdown]
# <a href="https://colab.research.google.com/github/faridsimba87-cpu/CDAV/blob/main/student_program_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("="*30)
print("Welcome to the Student Program")
print("="*30)
students = {}
while True:
    name = input("Enter student name (press Enter to stop): ")
    if name == "":
        break

    subject1 = input("Enter subject 1: ")
    subject2 = input("Enter subject 2: ")
    subject3 = input("Enter subject 3: ")

    score1 = int(input(f"Enter score for {subject1} : "))
    score2 = int(input(f"Enter Score for {subject2}: "))
    score3 = int(input(f"Enter Score for {subject3}: "))

    students[name] = {
        "subjects": [subject1, subject2, subject3],
        "scores": [score1, score2, score3]
    }

for name, details in students.items():
    print(f"\nStudent: {name}")
    print(f"Subject:  {details['subjects']}")
    print(f"Scores:  {details['scores']}")

    failing = [score for score in details["scores"] if score < 50]

    if failing:
        print(f"Failing Scores: {failing}")
    else:
        print("Passed everything!")
print("="*75)
print('''Thank you for using the student program rate our services at +245713604243''')
print("="*75)
# Out:
# ...
# Welcome to the Student Program
# ...
# Enter student name (press Enter to stop): farid
# Enter subject 1: math
# Enter subject 2: kisw
# Enter subject 3: eng
# Enter score for math : 99
# Enter Score for kisw: 78
# Enter Score for eng: 49
# Enter student name (press Enter to stop):
#
# Student: farid
# Subject:  ['math', 'kisw', 'eng']
# Scores:  [99, 78, 49]
# Failing Scores: [49]
# ...
# Thank you for using the student program rate our services at +245713604243
# ...
