# %% [markdown]
# <a href="https://colab.research.google.com/github/faridsimba87-cpu/CDAV/blob/main/Morning_brainstorm_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #body mass index
# Write a program that computes the body mass index (BMI) of an individual. Your
# program should begin by reading a height and weight from the user. Then it should
# use one of the following two formulas to compute the BMI before displaying it. If
# you read the height in inches and the weight in pounds then body mass index is
# computed using the following formula:
# BMI = weight
# height × height × 703.
# If you read the height in meters and the weight in kilograms then body mass index
# is computed using this slightly simpler formula:
# BMI = weight
# height × height .

# %%
print("Choose your preferred unit system:")
print("1. BMI (kilograms and meters)")
print("2. BMI (pounds and inches)")

choice = input("Enter your choice (1 or 2): ")

if choice == '1':
    weight = float(input("Enter your weight in kilograms: "))
    height = float(input("Enter your height in meters: "))
    if height > 0:
        bmi = weight / (height * height)
        print(f"Your BMI is: {bmi}")
    else:
        print("Height cannot be zero.")
elif choice == '2':
    weight_l = float(input("Enter your weight in pounds: "))
    height_1 = float(input("Enter your height in inches: "))
    if height_1 > 0:
        bmi = (weight_l / (height_1 * height_1)) * 703
        print(f"Your BMI is: {bmi}")
    else:
        print("Height cannot be zero.")
else:
    print("Invalid choice. Please enter 1 or 2.")
# Out:
# Choose your preferred unit system:
# 1. BMI (kilograms and meters)
# 2. BMI (pounds and inches)
# Enter your choice (1 or 2): 1
# Enter your weight in kilograms: 80.2
# Enter your height in meters: 4.2
# Your BMI is: 4.546485260770975

# %% [markdown]
# #sort 3 integers
# Create a program that reads three integers from the user and displays them in sorted
# order (from smallest to largest). Use the min and max functions to find the smallest
# and largest values. The middle value can be found by computing the sum of all three
# values, and then subtracting the minimum value and the maximum value.

# %%
inte=(input("Enter three integers separated by spaces: "))
inte_list=inte.split()
num1=int(inte_list[0])
num2=int(inte_list[1])
num3=int(inte_list[2])
min_num=min(num1,num2,num3)
max_num=max(num1,num2,num3)
mid_num=(num1+num2+num3)-min_num-max_num
print("Sorted order:",min_num,mid_num,max_num)
# Out:
# Enter three integers separated by spaces: 9 1 5
# Sorted order: 1 5 9

# %% [markdown]
# #sum of digits in an integer
# Develop a program that reads a four-digit integer from the user and displays the sum
# of the digits in the number. For example, if the user enters 3141 then your program
# should display 3+1+4+1=9.

# %%
number_str = input("Enter a four-digit integer: ")

if not (number_str.isdigit() and len(number_str) == 4):
    print("Please enter a valid four-digit integer.")
else:
    number = int(number_str)

    digit1 = number // 1000
    digit2 = (number // 100) % 10
    digit3 = (number // 10) % 10
    digit4 = number % 10

    sum_of_digits = digit1 + digit2 + digit3 + digit4

    print(f"{digit1}+{digit2}+{digit3}+{digit4}={sum_of_digits}")
# Out:
# Enter a four-digit integer: 1234
# 1+2+3+4=10
