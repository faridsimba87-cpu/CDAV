# %% [markdown]
# <a href="https://colab.research.google.com/github/faridsimba87-cpu/CDAV/blob/main/Used_cars_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# dataframe is a series that shares an index

# %%
pip install pandas

# %%
import pandas as pd
pd.__version__
pd.set_option('display.max_columns', None)

# %%
counties = pd.Series([14397073, 1208333, 2162202, 1157873])
print(counties)
# Out:
# 0    14397073
# 1     1208333
# 2     2162202
# 3     1157873
# dtype: int64

# %%
df = pd.read_csv("/content/used_cars_data.csv")
df.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# ...

# %%
df.tail()
# Out:
#       S.No.                                               Name   Location  \
# 7248   7248                  Volkswagen Vento Diesel Trendline  Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI     Mumbai
# 7250   7250                             Nissan Micra Diesel XV    Kolkata
# 7251   7251                             Volkswagen Polo GT TSI       Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...      Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 7248  2011              89411    Diesel       Manual      First  20.54 kmpl
# 7249  2015              59000    Petrol    Automatic      First  17.21 kmpl
# 7250  2012              28000    Diesel       Manual      First  23.08 kmpl
# 7251  2013              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252  2014              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats New_Price  Price
# ...

# %%
df.shape
# Out:
# (7253, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7207 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %%
df.describe()
# Out:
#              S.No.         Year  Kilometers_Driven        Seats        Price
# count  7253.000000  7253.000000       7.253000e+03  7200.000000  6019.000000
# mean   3626.000000  2013.365366       5.869906e+04     5.279722     9.479468
# std    2093.905084     3.254421       8.442772e+04     0.811660    11.187917
# min       0.000000  1996.000000       1.710000e+02     0.000000     0.440000
# 25%    1813.000000  2011.000000       3.400000e+04     5.000000     3.500000
# 50%    3626.000000  2014.000000       5.341600e+04     5.000000     5.640000
# 75%    5439.000000  2016.000000       7.300000e+04     5.000000     9.950000
# max    7252.000000  2019.000000       6.500000e+06    10.000000   160.000000

# %%
df["Seats"].unique()
# Out:
# array([ 5.,  7.,  8.,  4.,  6.,  2., nan, 10.,  9.,  0.])

# %%
df["Seats"].nunique()
# Out:
# 9

# %%
df["Seats"]
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       7.0
# 4       5.0
#        ...
# 7248    5.0
# 7249    5.0
# 7250    5.0
# 7251    5.0
# 7252    5.0
# Name: Seats, Length: 7253, dtype: float64

# %%
df[["Seats","Price"]]
# Out:
#       Seats  Price
# 0       5.0   1.75
# 1       5.0  12.50
# 2       5.0   4.50
# 3       7.0   6.00
# 4       5.0  17.74
# ...     ...    ...
# 7248    5.0    NaN
# 7249    5.0    NaN
# 7250    5.0    NaN
# 7251    5.0    NaN
# 7252    5.0    NaN
#
# [7253 rows x 2 columns]

# %%
df.loc[4, "Year"] #row labelled 2, column named county
df.iloc[1, 4] #row labelled 2, column 4
# Out:
# np.int64(41000)

# %%
#filtering in pandas
df["Transmission"]== "Manual"
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 7248     True
# 7249    False
# 7250     True
# 7251    False
# 7252    False
# Name: Transmission, Length: 7253, dtype: bool

# %%
#meaning not equal to sth
df["Transmission"]!= "Manual"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 7248    False
# 7249     True
# 7250    False
# 7251     True
# 7252     True
# Name: Transmission, Length: 7253, dtype: bool

# %%
s=pd.Series([10,20,30,40,44])
s>20
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# dtype: bool

# %%
#this expression means that: from this table,give me the rows where and look at the kilometers_driven column and also look at the condition
df[df["Kilometers_Driven"]>41000]
# Out:
#       S.No.                                               Name   Location  \
# 0         0                             Maruti Wagon R LXI CNG     Mumbai
# 2         2                                       Honda Jazz V    Chennai
# 3         3                                  Maruti Ertiga VDI    Chennai
# 5         5                    Hyundai EON LPG Era Plus Option  Hyderabad
# 6         6                             Nissan Micra Diesel XV     Jaipur
# ...     ...                                                ...        ...
# 7245   7245                              Honda Amaze S i-Vtech      Kochi
# 7248   7248                  Volkswagen Vento Diesel Trendline  Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI     Mumbai
# 7251   7251                             Volkswagen Polo GT TSI       Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...      Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
#display will be for kilometers driven more than 41000 and that use a manual transmission only
is_kilometers_driven = df["Kilometers_Driven"]>41000
is_transmission = df["Transmission"]=="Manual"
df[is_kilometers_driven & is_transmission]
# Out:
#       S.No.                               Name    Location  Year  \
# 0         0             Maruti Wagon R LXI CNG      Mumbai  2010
# 2         2                       Honda Jazz V     Chennai  2011
# 3         3                  Maruti Ertiga VDI     Chennai  2012
# 5         5    Hyundai EON LPG Era Plus Option   Hyderabad  2012
# 6         6             Nissan Micra Diesel XV      Jaipur  2013
# ...     ...                                ...         ...   ...
# 7240   7240            Honda Jazz 1.5 V i DTEC  Coimbatore  2017
# 7243   7243     Renault Duster 85PS Diesel RxL     Chennai  2015
# 7244   7244              Chevrolet Aveo 1.4 LS        Pune  2009
# 7245   7245              Honda Amaze S i-Vtech       Kochi  2015
# 7248   7248  Volkswagen Vento Diesel Trendline   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# ...

# %%
is_kilometers_driven.shape#rows and columns
# Out:
# (7253,)

# %%
len(is_kilometers_driven)#just the row count
# Out:
# 7253

# %%
#display will be for kilometers driven more than 41000 or that use a manual transmission only
is_kilometers_driven = df["Kilometers_Driven"]>41000
is_transmission = df["Transmission"]=="Manual"
df[is_kilometers_driven | is_transmission]
# Out:
#       S.No.                                               Name   Location  \
# 0         0                             Maruti Wagon R LXI CNG     Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option       Pune
# 2         2                                       Honda Jazz V    Chennai
# 3         3                                  Maruti Ertiga VDI    Chennai
# 5         5                    Hyundai EON LPG Era Plus Option  Hyderabad
# ...     ...                                                ...        ...
# 7248   7248                  Volkswagen Vento Diesel Trendline  Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI     Mumbai
# 7250   7250                             Nissan Micra Diesel XV    Kolkata
# 7251   7251                             Volkswagen Polo GT TSI       Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...      Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...
