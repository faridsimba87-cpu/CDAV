# %% [markdown]
# <a href="https://colab.research.google.com/github/faridsimba87-cpu/CDAV/blob/main/wk2_day2_brainstorm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exercise 108:Negatives,Zeros and Positives
# Create a program that reads integers from the user until a blank line is entered. Once
# all of the integers have been read your program should display all of the negative
# numbers,followed by all of the zeros,followed by all of the positive numbers.Within
# each group the numbers should be displayed in the same order that they were entered
# by the user. For example, if the user enters the values 3,-4, 1, 0,-1, 0, and-2 then
# your program should output the values-4,-1,-2, 0, 0, 3, and 1. Your program
# should display each value on its own line.

# %%
negatives = []
zeros = []
positives = []
while True:
    user_input = input("Enter an integer (or press Enter to quit): ")
    if user_input == "":
        break
    num = int(user_input)
    if num < 0:
        negatives.append(num)
    elif num == 0:
        zeros.append(num)
    else:
        positives.append(num)
for n in negatives:
    print(n)
for z in zeros:
    print(z)
for p in positives:
    print(p)
# Out:
# Enter an integer (or press Enter to quit): 3
# Enter an integer (or press Enter to quit): 2
# Enter an integer (or press Enter to quit): 6
# Enter an integer (or press Enter to quit): -2
# Enter an integer (or press Enter to quit): -4
# Enter an integer (or press Enter to quit): 0
# Enter an integer (or press Enter to quit): 0
# Enter an integer (or press Enter to quit): -1
# Enter an integer (or press Enter to quit):
# -2
# -4
# -1
# 0
# 0
# 3
# 2
# 6

# %% [markdown]
# In this exercise, you will create a program that reads words from the user until the
# user enters a blank line. After the user enters a blank line your program should display each word entered by the user exactly once. The words should be displayed in
# the same order that they were entered. For example, if the user enters:
# first
# second
# first
# third
# second
# then your program should display:
# first
# second
# third

# %%
name_list = []
while True:
    user_input = input("Enter a name (or press Enter to quit): ")
    if user_input == "":
        break
    if user_input not in name_list:
        name_list.append(user_input)
for n in name_list:
    print(n)
# Out:
# Enter a name (or press Enter to quit): name
# Enter a name (or press Enter to quit): boy
# Enter a name (or press Enter to quit): toy
# Enter a name (or press Enter to quit): boy
# Enter a name (or press Enter to quit):
# name
# boy
# toy
