# %% [markdown]
# <a href="https://colab.research.google.com/github/faridsimba87-cpu/CDAV/blob/main/Lilhomie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introduction to python

# %%
print(10)
# Out:
# 10

# %%
Current_year=2026
Current_year=2028
Birth_year=2005
Age=Current_year-Birth_year
print(Age)
# Out:
# 23

# %%
print(2026-2005)
# Out:
# 21

# %%
name="Farid"
Years="20"
Hobby= "Playing football"
print("My name is", name )
print(f"I am {Years} years old")
print(f"My hobby is {Hobby}",)
# Out:
# My name is Farid
# I am 20 years old
# My hobby is Playing football

# %%
name="Farid"
age="20Years"
print(name)
print(age)
# Out:
# Farid
# 20Years

# %% [markdown]
# # Input

# %%
name= input("what is your name ")
# Out:
# what is your name Farid

# %%
print(name)
# Out:
# Farid

# %%
name=input("what is your name? " )
food=input("what is your favorite food? " )
sport=input("what is your favourite sport? " )
print(f"Hello {name}!")
print(f"You like {food}.")
print(f"Your favourite sport is {sport}.")
# Out:
# what is your name? Farid
# what is your favorite food? Pizza
# what is your favourite sport? Football
# Hello Farid!
# You like Pizza.
# Your favourite sport is Football.

# %%
type("hello")
# Out:
# str

# %%
name="johm"
type(name)
# Out:
# str

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
name=3.22
type(name)
# Out:
# float

# %%
is_raining=True
is_sunny=False
print(type(is_raining))
# Out:
# <class 'bool'>

# %% [markdown]
# # Operators

# %%
print(1+1)
print(10*10)
print(20/2)
print(5//2)
print(5%2)
# Out:
# 2
# 100
# 10.0
# 2
# 1

# %% [markdown]
# # Type casting
#
# ---
#
# This is the process of changing oone data type to another
#
# Use the destination datatype's form as a function()

# %%
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
x=float(x)
print(type(x))
print(x)
# Out:
# <class 'float'>
# 10.0

# %%
x=10
float(x)
# Out:
# 10.0

# %%
degree = float(input("what is your body temperature in degrees? " ))
fereinheit = (degree*1.8) + 32
print("your body temperature in farenheit is",fereinheit)
# Out:
# what is your body temperature in degrees? 54
# your body temperature in farenheit is 129.2

# %%
#Mini Calc
no1=float(input("Enter a number"))
no2=float(input("Enter another number"))
print("sum is",no1+no2)
print("difference is",no1-no2)
print("product is",no1*no2)
print("division is",no1/no2)
print("the power is",no1**no2)
print("floor is",no1//no2)
print("reminder is",no1%no2)
# Out:
# Enter a number9
# Enter another number4
# sum is 13.0
# difference is 5.0
# product is 36.0
# division is 2.25
# the power is 6561.0
# floor is 2.0
# reminder is 1.0
