# %% [markdown]
# <a href="https://colab.research.google.com/github/faridsimba87-cpu/CDAV/blob/main/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Decision Making in python
# IF statements
#
# IF boolean_condition:
#
#     body of if

# %%
is_raining=True
if is_raining:
    print("stay indoors")
# Out:
# stay indoors

# %%
if not is_raining:
    print("go outside")

# %% [markdown]
# # BANK ATM-v1

# %%
balance=500
withdrawal_amount=float(input("How much do you want to withdraw"))
if withdrawal_amount>balance:
  print("You have insufficient balance")
if balance>=withdrawal_amount:
  print("withdrawal successful")
# Out:
# How much do you want to withdraw450
# withdrawal successful

# %% [markdown]
# Example: for an if statement to prompt one to enter their scores

# %%
marks=int(input("Please enter your marks "))
if marks>=50:
  print("congratulations you passed ")
if marks<50:
  print("sorry you failed")
# Out:
# Please enter your marks 68
# congratulations you passed

# %% [markdown]
# ## If else

# %%
marks=int(input("Please enter your marks "))
if marks>=50:
  print("congratulations you passed ")
else:
  print("sorry you failed")
# Out:
# Please enter your marks 48
# sorry you failed

# %% [markdown]
# Security task

# %%
password=input("Please enter the password" )
if password=="python123":
  print("Access granted")
else:
  print("Access denied")
# Out:
# Please enter the password1234
# Access denied

# %% [markdown]
# Multiple decisions(elif)

# %%
is_raining=input("if it is raning say yes. if not say no" )
is_cloudy=input("if it is cloudy say yes. if not say no" )
if is_raining=="yes":
  print("use an umbrella")
elif is_cloudy=="yes":
  print("carry an umbrella")
else:
  print("don't need an umbrella")
# Out:
# if it is raning say yes. if not say nono
# if it is cloudy say yes. if not say nono
# don't need an umbrella

# %% [markdown]
# #grade converter
# it takes the grade and tells the range of the marks

# %%
grade=input("Enter your grade ")
if grade=="A":
  print("80-100")
elif grade=="B":
  print("70-79")
elif grade=="C":
  print("61-69")
elif grade=="D":
  print("50-60")
elif grade=="E":
  print("40-49")
elif grade=="F":
  print("0-39")
else:
  print("you did not enter a valid grade")
# Out:
# Enter your grade B
# 70-79

# %% [markdown]
# #Multuple boolean expressions
# Remember for an expression that has (and)all the outputs will be false unless both the choices are true
#
# For another expression that has (or)all the outputs are true if one choice is true and will read false only if both the choices are false

# %%
a=1
b=2
c=3
print(a==b and b==c)
print(a<b or b>c)
print(a<b and b>c)
# Out:
# False
# True
# False

# %% [markdown]
# write a program that takes a value from the user. the program should print
#
# .divisible by two if the value is divisible by two
#
# .divisible by three if the value is divisible by three
#
# .divisible by both two and three if the value is divisible by both two and three
#
# otherwise it should print not divisibe by both two and three

# %%
number=int(input("Enter a number"))
if number == (f"number%2 is 0"):
  print("divisible by two")
elif number == (f"number%3 is 0"):
  print("divisible by three")
elif number == (f"number%2 and 3 is 0"):
  print("divisible by both two and three")
else:
  print("not divisible by both two and three")
# Out:
# Enter a number6
# not divisible by both two and three

# %% [markdown]
# #Example

# %%
score=int(input("Enter your score: "))
if score >=80:
  print("A")
elif score >=70 and score <80:
  print("B")
elif score >=60 and score <70:
  print("C")
elif score >=50 and score <60:
  print("D")
else:
  print("E")
# Out:
# Enter your score: 69
# C

# %% [markdown]
# #Example 2
# In many jurisdictions a small deposit is added to drink containers to encourage people
# to recycle them. In one particular jurisdiction, drink containers holding one liter or
# less have a $0.10 deposit, and  drink  containers holding more than one liter have a
# $0.25 deposit.
# Write a program that reads the number of containers of each size from the user.
# Your program should continue by computing and displaying the refund that will be
# received for returning those containers. Format the output so that it includes a dollar
# sign and always displays exactly two decimal places

# %%
SMALL_DEPOSIT = 0.10
LARGE_DEPOSIT = 0.25
small_containers = int(input("Enter the number of containers 1 liter or less: "))
large_containers = int(input("Enter the number of containers more than 1 liter: "))
refund = (small_containers * SMALL_DEPOSIT) + (large_containers * LARGE_DEPOSIT)
print(f"Refund: ${refund:.2f}")
# Out:
# Enter the number of containers 1 liter or less: 15
# Enter the number of containers more than 1 liter: 17
# Refund: $5.75

# %% [markdown]
# In this exercise you will create a program that reads a letter of the alphabet from the
# user. If the user enters a, e, i, o or u then your program should display a message
# indicating that the entered letter is a vowel. If the user enters y then your program
# should display a message indicating that sometimes y is a vowel, and sometimes y is
# a consonant. Otherwise your program should display a message indicating that the
# letter is a consonant

# %% [markdown]
# #Morning Examples
# In this exercise you will create a program that reads a letter of the alphabet from the
# user. If the user enters a, e, i, o or u then your program should display a message
# indicating that the entered letter is a vowel. If the user enters y then your program
# should display a message indicating that sometimes y is a vowel, and sometimes y is
# a consonant. Otherwise your program should display a message indicating that the
# letter is a consonant

# %%
letter=input("Enter a letter of the alphabet ")
if letter=="a" or letter=="e" or letter=="i" or letter=="o" or letter=="u":
  print("The letter is a vowel")
elif letter=="y":
  print("Sometimes y is a vowel, and sometimes y is a consonant")
else:
  print("letter given is a consonant")
# Out:
# Enter a letter of the alphabet s
# letter given is a consonant

# %% [markdown]
# #Exercise 39:Sound Levels
# The following table lists the sound level in decibels for several common noises.
#
# Noise in Decibellevel(dB)
# Jackhammer 130
# Gas lawnmower 106
# Alarm clock 70
# Quiet room 40
# Write a program that reads a sound level in decibels from the user. If the user
# enters a decibel level that matches one of the noises in the table then your program
# should display a message containing only that noise. If the user enters a number
# of decibels between the noises listed then your program should display a message
# indicating which noises the level isbetween.Ensurethatyourprogramalsogenerates
# reasonable output for a value smaller than the quietest noise in the table, and for a
# value larger than the loudest noise in the table

# %%
decibel_level = int(input("Enter a sound level in decibels: "))
if  decibel_level >=40 and decibel_level < 70:
    print("The level is between Quiet room and Alarm clock")
elif decibel_level >=70 and decibel_level < 106:
    print("The level is between Alarm clock and Gas lawnmower")
if  decibel_level >=106 and decibel_level < 130:
    print("The level is between Gas lawnmower and Jackhammer")
elif decibel_level > 130:
    print("The level is larger than the loudest noise in the table")
elif decibel_level < 40:
    print("The level is smaller than the quietest noise in the table")
elif decibel_level == 130:
    print("Jackhammer")
elif decibel_level == 106:
    print("Gas lawnmower")
elif decibel_level == 70:
    print("Alarm clock")
elif decibel_level == 40:
    print("Quiet room")
else:
    print("The level is not in the table")
# Out:
# Enter a sound level in decibels: 39
# The level is smaller than the quietest noise in the table

# %% [markdown]
# #Example from the chess question which is no. 45 in the python workbook
# Positions on a chess board are identified by a letter and a number.Theletteridentifies
# the column, while the number identifies the row, as shown below:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# a b c d e f g h
# Write a program that reads a position from the user. Use an if statement to deter
# mine if the column begins with a black square or a white square. Then use modular
# arithmetic to report the color of the square in that row. For example, if the user enters
# a1 then your program should report that the square is black. If the user enters d5
# then your program should report that the square is white. Your program may assume
# that a valid position will always be entered. It does not need to perform any error
# checking.

# %%
position=input("Enter your position ")
if position=="a1" or position=="a3" or position=="a5" or position=="a7":
  print("Black")
elif position=="b1" or position=="b3" or position=="b5" or position=="b7":
  print("White")
elif position=="c1" or position=="c3" or position=="c5" or position=="c7":
  print("Black")
elif position=="d1" or position=="d3" or position=="d5" or position=="d7":
  print("White")
elif position=="e1" or position=="e3" or position=="e5" or position=="e7":
  print("Black")
elif position=="f1" or position=="f3" or position=="f5" or position=="f7":
  print("White")
elif position=="g1" or position=="g3" or position=="g5" or position=="g7":
  print("Black")
elif position=="h1" or position=="h3" or position=="h5" or position=="h7":
  print("White")
elif position=="a2" or position=="a4" or position=="a6" or position=="a8":
  print("White")
elif position=="b2" or position=="b4" or position=="b6" or position=="b8":
  print("Black")
elif position=="c2" or position=="c4" or position=="c6" or position=="c8":
  print("White")
elif position=="d2" or position=="d4" or position=="d6" or position=="d8":
  print("Black")
elif position=="e2" or position=="e4" or position=="e6" or position=="e8":
  print("White")
elif position=="f2" or position=="f4" or position=="f6" or position=="f8":
  print("Black")
elif position=="g2" or position=="g4" or position=="g6" or position=="g8":
  print("White")
elif position=="h2" or position=="h4" or position=="h6" or position=="h8":
  print("Black")
else:
  print("white")
# Out:
# Enter your position z4
# white

# %% [markdown]
# #another way to deal with this exercise via chatgpt

# %%
position = input("Enter a chess board position (e.g., a1, d5): ")
column = position[0].lower()
row = int(position[1])
if column in ['a', 'c', 'e', 'g']:
    if row % 2 == 1:
        print("The square is black.")
    else:
        print("The square is white.")
else:
    if row % 2 == 1:
        print("The square is white.")
    else:
        print("The square is black.")
# Out:
# Enter a chess board position (e.g., a1, d5): z10
# The square is white.
